# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv('vehicles_messy.csv')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data.head()
# Out:
#    barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0  15.695714         0.0        0.0        0.0      19      0.0        0
# 1  29.964545         0.0        0.0        0.0       9      0.0        0
# 2  12.207778         0.0        0.0        0.0      23      0.0        0
# 3  29.964545         0.0        0.0        0.0      10      0.0        0
# 4  17.347895         0.0        0.0        0.0      17      0.0        0
#
#    cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                       createdOn                    modifiedOn  startStop  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37843 entries, 0 to 37842
# Data columns (total 83 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        37843 non-null  float64
#  1   barrelsA08       37843 non-null  float64
#  2   charge120        37843 non-null  float64
#  3   charge240        37843 non-null  float64
#  4   city08           37843 non-null  int64
#  5   city08U          37843 non-null  float64
#  6   cityA08          37843 non-null  int64
#  7   cityA08U         37843 non-null  float64
#  8   cityCD           37843 non-null  float64
#  9   cityE            37843 non-null  float64
#  10  cityUF           37843 non-null  float64
#  11  co2              37843 non-null  int64
#  12  co2A             37843 non-null  int64
#  13  co2TailpipeAGpm  37843 non-null  float64
#  14  co2TailpipeGpm   37843 non-null  float64
#  15  comb08           37843 non-null  int64
# ...

# %%
data.tail()
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 37838  14.982273         0.0        0.0        0.0      19      0.0        0
# 37839  14.330870         0.0        0.0        0.0      20      0.0        0
# 37840  15.695714         0.0        0.0        0.0      18      0.0        0
# 37841  15.695714         0.0        0.0        0.0      18      0.0        0
# 37842  18.311667         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 37838       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 37839       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 37840       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 37841       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 37842       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
# ...

# %%
null_cols=data.isnull().sum()
null_cols.c240bDscr
# Out:
# 37807

# %%
null_cols[null_cols>0]
# Out:
# cylinders       123
# displ           120
# drive          1189
# eng_dscr      15403
# trany            11
# guzzler       35562
# trans_dscr    22796
# tCharger      32657
# sCharger      37177
# atvType       34771
# fuelType2     36435
# rangeA        36440
# evMotor       37281
# mfrCode       30818
# c240Dscr      37806
# c240bDscr     37807
# startStop     31705
# dtype: int64

# %%
null_cols[null_cols==0]
# Out:
# barrels08     0
# barrelsA08    0
# charge120     0
# charge240     0
# city08        0
#              ..
# createdOn     0
# modifiedOn    0
# phevCity      0
# phevHwy       0
# phevComb      0
# Length: 66, dtype: int64

# %%
null_cols=data.isnull().mean()*100
null_cols=null_cols[null_cols>0].sort_values()
null_cols
# Out:
# trany          0.029067
# displ          0.317100
# cylinders      0.325027
# drive          3.141928
# eng_dscr      40.702376
# trans_dscr    60.238353
# mfrCode       81.436461
# startStop     83.780356
# tCharger      86.296012
# atvType       91.882250
# guzzler       93.972465
# fuelType2     96.279365
# rangeA        96.292577
# sCharger      98.240097
# evMotor       98.514917
# c240Dscr      99.902228
# c240bDscr     99.904870
# dtype: float64

# %%
cols_eliminate=list(null_cols[null_cols>=40].index)

# %%
data_clean=data.drop(cols_eliminate,axis=1)
data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37843 entries, 0 to 37842
# Data columns (total 70 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   barrels08        37843 non-null  float64
#  1   barrelsA08       37843 non-null  float64
#  2   charge120        37843 non-null  float64
#  3   charge240        37843 non-null  float64
#  4   city08           37843 non-null  int64
#  5   city08U          37843 non-null  float64
#  6   cityA08          37843 non-null  int64
#  7   cityA08U         37843 non-null  float64
#  8   cityCD           37843 non-null  float64
#  9   cityE            37843 non-null  float64
#  10  cityUF           37843 non-null  float64
#  11  co2              37843 non-null  int64
#  12  co2A             37843 non-null  int64
#  13  co2TailpipeAGpm  37843 non-null  float64
#  14  co2TailpipeGpm   37843 non-null  float64
#  15  comb08           37843 non-null  int64
# ...

# %%
null_displ=data_clean[data_clean['displ'].isnull()==True]
null_displ
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08   city08U  cityA08  \
# 7138       0.240         0.0        0.0        0.0      81    0.0000        0
# 7139       0.282         0.0        0.0        0.0      81    0.0000        0
# 8143       0.282         0.0        0.0        0.0      81    0.0000        0
# 8144       0.312         0.0        0.0        0.0      74    0.0000        0
# 8146       0.522         0.0        0.0        0.0      45    0.0000        0
# ...          ...         ...        ...        ...     ...       ...      ...
# 30969      0.192         0.0        0.0        4.0     120  119.6000        0
# 30972      0.204         0.0        0.0       10.0      98   97.5636        0
# 30973      0.192         0.0        0.0       12.0     101  101.4750        0
# 30974      0.210         0.0        0.0       12.0      92   92.4713        0
# 30975      0.216         0.0        0.0       12.0      91   91.2362        0
#
# ...

# %%
null_displ=null_displ[['year','make','model','cylinders','displ']]

# %%
null_displ
# Out:
#        year    make                            model  cylinders  displ
# 7138   2000  Nissan                         Altra EV        NaN    NaN
# 7139   2000  Toyota                          RAV4 EV        NaN    NaN
# 8143   2001  Toyota                          RAV4 EV        NaN    NaN
# 8144   2001    Ford                            Th!nk        NaN    NaN
# 8146   2001    Ford           Explorer USPS Electric        NaN    NaN
# ...     ...     ...                              ...        ...    ...
# 30969  2017     Kia                    Soul Electric        NaN    NaN
# 30972  2016   Tesla  Model S (60 kW-hr battery pack)        NaN    NaN
# 30973  2016   Tesla                Model S AWD - 60D        NaN    NaN
# 30974  2016   Tesla              Model S AWD - P100D        NaN    NaN
# 30975  2016   Tesla                Model X AWD - 60D        NaN    NaN
#
# [120 rows x 5 columns]

# %%
data_clean[['displ','cylinders']]=data_clean[['displ','cylinders']].fillna(0)

# %%
data_clean
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 37838  14.982273         0.0        0.0        0.0      19      0.0        0
# 37839  14.330870         0.0        0.0        0.0      20      0.0        0
# 37840  15.695714         0.0        0.0        0.0      18      0.0        0
# 37841  15.695714         0.0        0.0        0.0      18      0.0        0
# 37842  18.311667         0.0        0.0        0.0      16      0.0        0
#
# ...

# %%
data_clean[['displ','cylinders']].isnull().sum()
# Out:
# displ        0
# cylinders    0
# dtype: int64

# %%
data_clean.keys()
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'feScore', 'fuelCost08', 'fuelCostA08',
#        'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA', 'highway08',
#        'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD', 'highwayE',
#        'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make', 'model',
#        'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'charge240b',
#        'createdOn', 'modifiedOn', 'phevCity', 'phevHwy', 'phevComb'],
#       dtype='object')

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar1', 'baz1', 'foo'],
                    'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                    'value': [5, 6, 7, 8]})

# %%
df1
# Out:
#    lkey  value
# 0   foo      1
# 1  bar1      2
# 2  baz1      3
# 3   foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
