# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/ITS/Time-Use-in-OECD (2021_08_13 15_24_06 UTC).csv')

# %%
df.head()
# Out:
#      Country  Paidwork  Education  Household  Housework  Shopping  Unpaid  \
# 0  Australia       211         27         45        132        29      58
# 1    Austria       280         27         34        125        21      32
# 2    Belgium       194         41         22        121        29      30
# 3     Canada       269         36         29        115        24      52
# 4      China       315         25         23        103        20      33
#
#    Sleep  Food  Personalcare  Sports  Events  Friends  TVRadio  Other
# 0    512    89            56      19       6       40      140     76
# 1    498    79            55      32       9       82      109     59
# 2    513    99            53      21      15       50      131    122
# 3    520    65            52      21       6       53      109     89
# 4    542   100            52      23       2       23      127     53

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       33 non-null     object
#  1   Paidwork      33 non-null     int64
#  2   Education     33 non-null     int64
#  3   Household     33 non-null     int64
#  4   Housework     33 non-null     int64
#  5   Shopping      33 non-null     int64
#  6   Unpaid        33 non-null     int64
#  7   Sleep         33 non-null     int64
#  8   Food          33 non-null     int64
#  9   Personalcare  33 non-null     int64
#  10  Sports        33 non-null     int64
#  11  Events        33 non-null     int64
#  12  Friends       33 non-null     int64
#  13  TVRadio       33 non-null     int64
#  14  Other         33 non-null     int64
# dtypes: int64(14), object(1)
# memory usage: 4.0+ KB

# %%
df_s= df.copy()
df_s.head()
# Out:
#      Country  Paidwork  Education  Household  Housework  Shopping  Unpaid  \
# 0  Australia       211         27         45        132        29      58
# 1    Austria       280         27         34        125        21      32
# 2    Belgium       194         41         22        121        29      30
# 3     Canada       269         36         29        115        24      52
# 4      China       315         25         23        103        20      33
#
#    Sleep  Food  Personalcare  Sports  Events  Friends  TVRadio  Other
# 0    512    89            56      19       6       40      140     76
# 1    498    79            55      32       9       82      109     59
# 2    513    99            53      21      15       50      131    122
# 3    520    65            52      21       6       53      109     89
# 4    542   100            52      23       2       23      127     53

# %%
df_s[['Education','Household']]=df_s[['Household','Education']]

# %%
df_s.head()
# Out:
#      Country  Paidwork  Education  Household  Housework  Shopping  Unpaid  \
# 0  Australia       211         45         27        132        29      58
# 1    Austria       280         34         27        125        21      32
# 2    Belgium       194         22         41        121        29      30
# 3     Canada       269         29         36        115        24      52
# 4      China       315         23         25        103        20      33
#
#    Sleep  Food  Personalcare  Sports  Events  Friends  TVRadio  Other
# 0    512    89            56      19       6       40      140     76
# 1    498    79            55      32       9       82      109     59
# 2    513    99            53      21      15       50      131    122
# 3    520    65            52      21       6       53      109     89
# 4    542   100            52      23       2       23      127     53

# %%
#loc: location

df.loc[0:5,'Country']
# Out:
# 0    Australia
# 1      Austria
# 2      Belgium
# 3       Canada
# 4        China
# 5      Denmark
# Name: Country, dtype: object

# %%
df.loc[0:15:2,'Country']
# Out:
# 0     Australia
# 2       Belgium
# 4         China
# 6       Estonia
# 8        France
# 10       Greece
# 12        India
# 14        Italy
# Name: Country, dtype: object

# %%
df.loc[0::3,'Country']
# Out:
# 0        Australia
# 3           Canada
# 6          Estonia
# 9          Germany
# 12           India
# 15           Japan
# 18       Lithuania
# 21     Netherlands
# 24          Poland
# 27    South Africa
# 30          Turkey
# Name: Country, dtype: object

# %%
df.loc[0::3,'Country':]
# Out:
#          Country  Paidwork  Education  Household  Housework  Shopping  Unpaid  \
# 0      Australia       211         27         45        132        29      58
# 3         Canada       269         36         29        115        24      52
# 6        Estonia       231         25         28        121        24      40
# 9        Germany       224         24         19        109        32      53
# 12         India       272         23         21        148        12      22
# 15         Japan       326         37          0         80        25      98
# 18     Lithuania       304         12         19        154        17      42
# 21   Netherlands       218         25         22        105        28      46
# 24        Poland       229         30         38        135        25      39
# 27  South Africa       189         39         18        130         9      41
# 30        Turkey       217         29         29        124        14      60
#
# ...

# %%
df.loc[0::3,'Country':'Shopping']
# Out:
#          Country  Paidwork  Education  Household  Housework  Shopping
# 0      Australia       211         27         45        132        29
# 3         Canada       269         36         29        115        24
# 6        Estonia       231         25         28        121        24
# 9        Germany       224         24         19        109        32
# 12         India       272         23         21        148        12
# 15         Japan       326         37          0         80        25
# 18     Lithuania       304         12         19        154        17
# 21   Netherlands       218         25         22        105        28
# 24        Poland       229         30         38        135        25
# 27  South Africa       189         39         18        130         9
# 30        Turkey       217         29         29        124        14

# %%
df.loc[0::3,'Country':'Shopping':2]
# Out:
#          Country  Education  Housework
# 0      Australia         27        132
# 3         Canada         36        115
# 6        Estonia         25        121
# 9        Germany         24        109
# 12         India         23        148
# 15         Japan         37         80
# 18     Lithuania         12        154
# 21   Netherlands         25        105
# 24        Poland         30        135
# 27  South Africa         39        130
# 30        Turkey         29        124

# %%
for i in range (0,50,5): print (i)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %%
#quiero que me traigas, de favor, los países que más tiempo le dedican al trabajo (i.e. mayor a 300 mins)
df[df.loc[:,'Paidwork']>300]
# Out:
#       Country  Paidwork  Education  Household  Housework  Shopping  Unpaid  \
# 4       China       315         25         23        103        20      33
# 15      Japan       326         37          0         80        25      98
# 17     Latvia       317         13         15        130        16      39
# 18  Lithuania       304         12         19        154        17      42
# 20     Mexico       302         45         38        187        14      46
#
#     Sleep  Food  Personalcare  Sports  Events  Friends  TVRadio  Other
# 4     542   100            52      23       2       23      127     53
# 15    442    93            85      10       0       17      103    148
# 17    512    89            40      25       5       35      123     81
# 18    503    88            54      16       1       32      137     61
# 20    499    77            58      14       7       44       66     41

# %%
df.loc[:,'Paidwork']>300
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17     True
# 18     True
# 19    False
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# Name: Paidwork, dtype: bool

# %%
#para cambiar los índices:
df_new_index=df.set_index('Country',drop=True)
df_new_index.head()
# Out:
#            Paidwork  Education  Household  Housework  Shopping  Unpaid  Sleep  \
# Country
# Australia       211         27         45        132        29      58    512
# Austria         280         27         34        125        21      32    498
# Belgium         194         41         22        121        29      30    513
# Canada          269         36         29        115        24      52    520
# China           315         25         23        103        20      33    542
#
#            Food  Personalcare  Sports  Events  Friends  TVRadio  Other
# Country
# Australia    89            56      19       6       40      140     76
# Austria      79            55      32       9       82      109     59
# Belgium      99            53      21      15       50      131    122
# Canada       65            52      21       6       53      109     89
# China       100            52      23       2       23      127     53

# %%
df_new_index.loc['Australia':'Belgium','Paidwork':'Housework']
# Out:
#            Paidwork  Education  Household  Housework
# Country
# Australia       211         27         45        132
# Austria         280         27         34        125
# Belgium         194         41         22        121

# %%
#iloc: con iloc identificamos con integer(i)

# %%
df.iloc[0:4,0:3]
# Out:
#      Country  Paidwork  Education
# 0  Australia       211         27
# 1    Austria       280         27
# 2    Belgium       194         41
# 3     Canada       269         36

# %%
df.iloc[[1,30],[3,10,1,0]]
# Out:
#     Household  Sports  Paidwork  Country
# 1          34      32       280  Austria
# 30         29       9       217   Turkey

# %%
df_new_index.iloc[[1,30],[2,9,0]]
# Out:
#          Household  Sports  Paidwork
# Country
# Austria         34      32       280
# Turkey          29       9       217

# %%
df_new_index['Paidwork']=df_new_index['Paidwork']/60

# %%
df_new_index
# Out:
#               Paidwork  Education  Household  Housework  Shopping  Unpaid  \
# Country
# Australia     0.058611         27         45        132        29      58
# Austria       0.077778         27         34        125        21      32
# Belgium       0.053889         41         22        121        29      30
# Canada        0.074722         36         29        115        24      52
# China         0.087500         25         23        103        20      33
# Denmark       0.055556         25         28        128        26      45
# Estonia       0.064167         25         28        121        24      40
# Finland       0.055556         29         23        109        26      81
# France        0.047222         34         22        129        22      17
# Germany       0.062222         24         19        109        32      53
# Greece        0.051944         40         19        125        16      26
# ...

# %%
df['Recreation']=df['Sports']/60+df['Events']/60+df['Friends']/60
df.head()
# Out:
#      Country  Paidwork  Education  Household  Housework  Shopping  Unpaid  \
# 0  Australia       211         27         45        132        29      58
# 1    Austria       280         27         34        125        21      32
# 2    Belgium       194         41         22        121        29      30
# 3     Canada       269         36         29        115        24      52
# 4      China       315         25         23        103        20      33
#
#    Sleep  Food  Personalcare  Sports  Events  Friends  TVRadio  Other  \
# 0    512    89            56      19       6       40      140     76
# 1    498    79            55      32       9       82      109     59
# 2    513    99            53      21      15       50      131    122
# 3    520    65            52      21       6       53      109     89
# 4    542   100            52      23       2       23      127     53
#
#    Recreation
# 0    1.083333
# 1    2.050000
# 2    1.433333
# 3    1.333333
# 4    0.800000

# %%
type(a)
# Out:
# float

# %%
#queremos de los países que terminan con "a" y que su tiempo de sueño es mayor 500m/día
df[(df['Country'].str.endswith('a'))&(df['Sleep']>500)]
# Out:
#          Country  Paidwork  Education  Household  Housework  Shopping  Unpaid  \
# 0      Australia       211         27         45        132        29      58
# 3         Canada       269         36         29        115        24      52
# 4          China       315         25         23        103        20      33
# 6        Estonia       231         25         28        121        24      40
# 12         India       272         23         21        148        12      22
# 17        Latvia       317         13         15        130        16      39
# 18     Lithuania       304         12         19        154        17      42
# 26      Slovenia       227         38         21        166        18      32
# 27  South Africa       189         39         18        130         9      41
#
#     Sleep  Food  Personalcare  Sports  Events  Friends  TVRadio  Other  \
# 0     512    89            56      19       6       40      140     76
# ...

# %%
#quiero que me traiga los 5 países que más trabajan
df.loc[:,['Country','Paidwork']].sort_values('Paidwork',ascending=False).head()
# Out:
#       Country  Paidwork
# 15      Japan       326
# 17     Latvia       317
# 4       China       315
# 18  Lithuania       304
# 20     Mexico       302

# %%
#si qusisera el promedio de sleep en horas
df['Sleep'].mean()/60.
# Out:
# 8.457575757575757
